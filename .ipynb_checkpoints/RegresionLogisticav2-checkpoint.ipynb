# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
import matplotlib.pyplot as plt 
plt.rc("font", size=14)
from sklearn.linear_model import LogisticRegression
#from sklearn.cross_validation import train_test_split
from sklearn.model_selection import train_test_split
import seaborn as sns
sns.set(style="white")
sns.set(style="whitegrid", color_codes=True)
# %matplotlib inline
data = pd.read_csv("adult.csv")

# %%
#Tamaño del conjunto de datos
data.shape  #tenemos 32561 filas y 15 columnas
# Out:
# (32561, 15)

# %%
data.head()
# Out:
#    age workclass  fnlwgt     education  education.num marital.status  \
# 0   90         ?   77053       HS-grad              9        Widowed
# 1   82   Private  132870       HS-grad              9        Widowed
# 2   66         ?  186061  Some-college             10        Widowed
# 3   54   Private  140359       7th-8th              4       Divorced
# 4   41   Private  264663  Some-college             10      Separated
#
#           occupation   relationship   race     sex  capital.gain  \
# 0                  ?  Not-in-family  White  Female             0
# 1    Exec-managerial  Not-in-family  White  Female             0
# 2                  ?      Unmarried  Black  Female             0
# 3  Machine-op-inspct      Unmarried  White  Female             0
# 4     Prof-specialty      Own-child  White  Female             0
#
#    capital.loss  hours.per.week native.country income
# 0          4356              40  United-States  <=50K
# 1          4356              18  United-States  <=50K
# 2          4356              40  United-States  <=50K
# 3          3900              40  United-States  <=50K
# 4          3900              40  United-States  <=50K

# %% [markdown]
# Para iniciar el modelo, realziamos un cambio "?" por nan, y luego elimino los nan, mi dataset es data_limpia

# %%
data_temp = data[data != '?']
data_limpia = data_temp.dropna()
data_limpia.head()
# Out:
#    age workclass  fnlwgt     education  education.num marital.status  \
# 1   82   Private  132870       HS-grad              9        Widowed
# 3   54   Private  140359       7th-8th              4       Divorced
# 4   41   Private  264663  Some-college             10      Separated
# 5   34   Private  216864       HS-grad              9       Divorced
# 6   38   Private  150601          10th              6      Separated
#
#           occupation   relationship   race     sex  capital.gain  \
# 1    Exec-managerial  Not-in-family  White  Female             0
# 3  Machine-op-inspct      Unmarried  White  Female             0
# 4     Prof-specialty      Own-child  White  Female             0
# 5      Other-service      Unmarried  White  Female             0
# 6       Adm-clerical      Unmarried  White    Male             0
#
#    capital.loss  hours.per.week native.country income
# 1          4356              18  United-States  <=50K
# 3          3900              40  United-States  <=50K
# 4          3900              40  United-States  <=50K
# 5          3770              45  United-States  <=50K
# 6          3770              40  United-States  <=50K

# %%
data_limpia.shape  #Cuantos quedan luego de eliminar
# Out:
# (30162, 15)

# %% [markdown]
# Se reduce la categoria en el atributo marital.status, para un mejor modelo se va agrupar en solteros y casados, Married y Never-Married

# %%
data["marital.status"].unique()
# Out:
# array(['Widowed', 'Divorced', 'Separated', 'Never-married',
#        'Married-civ-spouse', 'Married-spouse-absent', 'Married-AF-spouse'], dtype=object)

# %%
data_limpia.loc[data_limpia["marital.status"]=="Widowed", "marital.status"]="Married"
data_limpia.loc[data_limpia["marital.status"]=="Divorced","marital.status"]="Married"
data_limpia.loc[data_limpia["marital.status"]=="Separated","marital.status"]="Married"
data_limpia.loc[data_limpia["marital.status"]=="Married-civ-spouse","marital.status"]="Married"
data_limpia.loc[data_limpia["marital.status"]=="Married-spouse-absent","marital.status"]="Married"
data_limpia.loc[data_limpia["marital.status"]=="Married-AF-spouse","marital.status"]="Married"
data_limpia.head()
# Out:
# C:\Users\Ferdinand\Anaconda3\lib\site-packages\pandas\core\indexing.py:537: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
#    age workclass  fnlwgt     education  education.num marital.status  \
# 1   82   Private  132870       HS-grad              9        Married
# 3   54   Private  140359       7th-8th              4        Married
# 4   41   Private  264663  Some-college             10        Married
# 5   34   Private  216864       HS-grad              9        Married
# 6   38   Private  150601          10th              6        Married
#
#           occupation   relationship   race     sex  capital.gain  \
# 1    Exec-managerial  Not-in-family  White  Female             0
# 3  Machine-op-inspct      Unmarried  White  Female             0
# 4     Prof-specialty      Own-child  White  Female             0
# 5      Other-service      Unmarried  White  Female             0
# 6       Adm-clerical      Unmarried  White    Male             0
#
#    capital.loss  hours.per.week native.country income
# 1          4356              18  United-States  <=50K
# 3          3900              40  United-States  <=50K
# 4          3900              40  United-States  <=50K
# 5          3770              45  United-States  <=50K
# 6          3770              40  United-States  <=50K

# %%
data_limpia["marital.status"].unique()
# Out:
# array(['Married', 'Never-married'], dtype=object)

# %% [markdown]
# # Exploracion de datos
# ### Analizamos la clase income

# %%
#Mostramos la clase income
data_limpia["income"].value_counts()
# Out:
# <=50K    22654
# >50K      7508
# Name: income, dtype: int64

# %%
sns.countplot(x=data_limpia["income"] )
plt.show()

# %%
#Calculo de la media de income con los atributos numericos
data_limpia.groupby(data_limpia["income"]).mean()
#se observa que capital.gain y capital.loss tienen mucha diferencia, en menor medida la age(edad) y horas
#por semana (hours.per.week)
# Out:
#              age         fnlwgt  education.num  capital.gain  capital.loss  \
# income
# <=50K   36.60806  190338.646729       9.629116    148.893838     53.448000
# >50K    43.95911  188149.962174      11.606420   3937.679808    193.750666
#
#         hours.per.week
# income
# <=50K        39.348592
# >50K         45.706580

# %% [markdown]
# Calculamos los atributos categoricos, respecto a los numericos, se puede realizar uno por uno

# %%
data_limpia.groupby("workclass").mean()
# Out:
#                         age         fnlwgt  education.num  capital.gain  \
# workclass
# Federal-gov       42.577943  185717.107105      10.948038    832.321315
# Local-gov         41.743106  188422.886309      11.036768    829.230285
# Private           36.794355  192719.985776       9.871085    879.858207
# Self-emp-inc      46.027933  175775.219739      11.167598   4810.746741
# Self-emp-not-inc  45.011605  175222.506603      10.211285   1913.134454
# State-gov         39.362002  184440.424550      11.349492    684.306489
# Without-pay       47.785714  174267.500000       9.071429    487.857143
#
#                   capital.loss  hours.per.week
# workclass
# Federal-gov         111.731707       41.279958
# Local-gov           110.323174       41.002419
# Private              79.629498       40.250875
# Self-emp-inc        153.504655       48.802607
# Self-emp-not-inc    115.572229       44.432173
# State-gov            81.147772       39.053948
# Without-pay           0.000000       32.714286

# %%
data_limpia.groupby("education").mean()
# Out:
#                     age         fnlwgt  education.num  capital.gain  \
# education
# 10th          37.897561  196969.587805            6.0    395.914634
# 11th          32.363550  193269.800573            7.0    217.190840
# 12th          32.013263  200397.411141            8.0    265.501326
# 1st-4th       44.622517  245258.609272            2.0    113.940397
# 5th-6th       41.649306  235891.625000            3.0    170.038194
# 7th-8th       47.631957  190912.093357            4.0    244.703770
# 9th           40.303297  204487.019780            5.0    354.298901
# Assoc-acdm    37.286706  192816.142857           12.0    554.921627
# Assoc-voc     38.246366  181140.203520           11.0    737.344300
# Bachelors     38.641554  187933.576328           13.0   1735.028747
# Doctorate     47.130667  188782.168000           16.0   5031.370667
# HS-grad       38.640955  189384.311484            9.0    589.385874
# Masters       43.740012  179991.526736           14.0   2554.357099
# Preschool     41.288889  237499.377778            1.0   1018.177778
# Prof-school   44.249077  185621.079336           15.0  10731.630996
# Some-college  36.135370  189140.219826           10.0    590.284816
#
#               capital.loss  hours.per.week
# education
# 10th             62.268293       37.464634
# 11th             52.538168       34.193702
# 12th             32.891247       35.697613
# 1st-4th          53.768212       38.377483
# 5th-6th          71.524306       38.798611
# 7th-8th          66.229803       40.131059
# 9th              28.980220       38.767033
# Assoc-acdm       94.377976       41.184524
# Assoc-voc        70.198929       41.954093
# Bachelors       117.964512       42.948454
# Doctorate       265.226667       47.832000
# HS-grad          70.790041       41.042073
# Masters         171.854333       44.240934
# Preschool        75.355556       36.866667
# Prof-school     234.474170       47.963100
# Some-college     71.902366       39.411051

# %%
data_limpia.groupby("marital.status").mean()
# Out:
#                       age         fnlwgt  education.num  capital.gain  \
# marital.status
# Married         43.185946  186981.619886      10.174349   1429.045214
# Never-married   28.461444  195702.779663      10.009870    383.834362
#
#                 capital.loss  hours.per.week
# marital.status
# Married           105.597328       42.689959
# Never-married      52.180136       37.235863

# %%
data_limpia.groupby("occupation").mean()
# Out:
#                          age         fnlwgt  education.num  capital.gain  \
# occupation
# Adm-clerical       37.004569  191949.896264      10.108035    497.097286
# Armed-Forces       30.222222  215425.888889      10.111111      0.000000
# Craft-repair       38.976675  192298.204963       9.117866    657.586849
# Exec-managerial    42.183116  184496.540331      11.438878   2185.330912
# Farming-fishing    41.251769  170381.319515       8.614762    592.707786
# Handlers-cleaners  32.114815  203602.637778       8.495556    258.140000
# Machine-op-inspct  37.693795  195200.527976       8.475585    323.825025
# Other-service      34.905978  188434.666252       8.778643    181.705479
# Priv-house-serv    42.034965  200711.699301       7.223776    291.594406
# Prof-specialty     40.462853  185098.634473      12.891035   2717.880139
# Protective-serv    38.925466  202401.984472      10.189441    713.596273
# Sales              37.389230  190942.271763      10.298270   1308.637835
# Tech-support       37.063596  191599.616228      10.967105    668.105263
# Transport-moving   40.252545  190181.492366       8.751908    498.121501
#
#                    capital.loss  hours.per.week
# occupation
# Adm-clerical          59.987638       37.561408
# Armed-Forces         209.666667       40.666667
# Craft-repair          86.510918       42.298015
# Exec-managerial      139.224198       44.966934
# Farming-fishing       63.394338       46.990900
# Handlers-cleaners     44.220000       37.874815
# Machine-op-inspct     58.526450       40.707019
# Other-service         36.874222       34.605542
# Priv-house-serv       22.349650       32.797203
# Prof-specialty       136.436107       42.374938
# Protective-serv       78.942547       42.846273
# Sales                 99.141183       40.763393
# Tech-support          98.311404       39.473684
# Transport-moving      82.776718       44.650127

# %%
data_limpia.groupby("relationship").mean()
# Out:
#                       age         fnlwgt  education.num  capital.gain  \
# relationship
# Husband         43.238707  186819.673754      10.345102   1794.521945
# Not-in-family   37.900337  191680.809345      10.370437    756.779834
# Other-relative  33.213723  206017.299213       8.762655    234.692913
# Own-child       25.186073  193500.518361       9.528661    162.003807
# Unmarried       40.335616  190790.042030       9.683998    474.256849
# Wife            39.897582  181480.642248      10.509246   1614.273826
#
#                 capital.loss  hours.per.week
# relationship
# Husband           125.540801       44.566637
# Not-in-family      75.725214       41.082708
# Other-relative     54.710911       37.359955
# Own-child          39.074787       33.353336
# Unmarried          40.446139       39.431818
# Wife              115.763869       37.628023

# %%
data_limpia.groupby("race").mean()
# Out:
#                           age         fnlwgt  education.num  capital.gain  \
# race
# Amer-Indian-Eskimo  36.737762  123491.944056       9.356643    660.290210
# Asian-Pac-Islander  37.910615  159337.400000      11.025698   1304.375419
# Black               37.860845  228807.455449       9.530706    604.722045
# Other               33.601732  195772.238095       8.683983   1060.653680
# White               38.580612  187285.002159      10.175491   1142.651024
#
#                     capital.loss  hours.per.week
# race
# Amer-Indian-Eskimo     37.164336       40.426573
# Asian-Pac-Islander     91.683799       40.500559
# Black                  56.267661       38.674476
# Other                  50.294372       40.112554
# White                  92.649558       41.204103

# %%
data_limpia.groupby("sex").mean()
# Out:
#               age         fnlwgt  education.num  capital.gain  capital.loss  \
# sex
# Female  36.883459  185926.150480      10.098651    570.176753     60.938765
# Male    39.184004  191650.246075      10.132188   1342.476546    101.540137
#
#         hours.per.week
# sex
# Female       36.932222
# Male         42.850687

# %%
data_limpia.groupby("native.country").mean()
# Out:
#                                   age         fnlwgt  education.num  \
# native.country
# Cambodia                    38.888889  189291.722222       8.722222
# Canada                      41.514019  181268.224299      10.672897
# China                       42.235294  178793.720588      11.235294
# Columbia                    39.339286  227963.910714       9.446429
# Cuba                        45.532609  248063.880435       9.695652
# Dominican-Republic          37.432836  193123.044776       7.089552
# Ecuador                     36.444444  186532.185185       9.555556
# El-Salvador                 34.720000  254135.100000       6.880000
# England                     41.255814  183293.767442      11.127907
# France                      39.888889  195377.222222      12.370370
# Germany                     39.695312  190883.492188      11.109375
# Greece                      46.206897  143466.206897       9.724138
# Guatemala                   32.412698  266158.031746       6.063492
# Haiti                       38.547619  209259.976190       8.857143
# Holand-Netherlands          32.000000   27882.000000      10.000000
# Honduras                    34.333333  251182.833333       8.666667
# Hong                        33.263158  222586.000000      10.894737
# Hungary                     49.384615  180488.461538      10.769231
# India                       38.090000  168539.090000      12.430000
# Iran                        39.833333  181502.904762      12.452381
# Ireland                     36.458333  137997.583333      10.083333
# Italy                       46.485294  182981.838235       8.735294
# Jamaica                     35.800000  214025.500000       9.812500
# Japan                       38.813559  190009.796610      11.355932
# Laos                        35.647059  217059.176471       8.647059
# Mexico                      33.181967  290478.945902       6.154098
# Nicaragua                   32.939394  295138.696970       8.666667
# Outlying-US(Guam-USVI-etc)  38.714286  204487.785714      10.285714
# Peru                        35.866667  277084.766667       9.433333
# Philippines                 39.755319  164504.893617      10.968085
# Poland                      41.660714  184288.982143      10.160714
# Portugal                    38.852941  145700.352941       6.852941
# Puerto-Rico                 40.146789  202286.963303       8.339450
# Scotland                    38.454545  172896.363636      10.363636
# South                       38.957746  166742.704225      11.056338
# Taiwan                      35.666667  194362.357143      13.476190
# Thailand                    35.705882  184271.352941      11.000000
# Trinadad&Tobago             42.666667  188008.944444       8.333333
# United-States               38.504290  187054.999491      10.222150
# Vietnam                     33.375000  165138.265625       9.515625
# Yugoslavia                  38.812500  215963.937500       9.937500
#
#                             capital.gain  capital.loss  hours.per.week
# native.country
# Cambodia                     1084.944444    104.222222       40.944444
# Canada                       1614.560748    146.934579       41.476636
# China                         404.205882    198.000000       38.647059
# Columbia                      190.285714     28.607143       39.642857
# Cuba                          379.206522     72.326087       39.728261
# Dominican-Republic           1542.149254     26.298507       42.283582
# Ecuador                       547.148148      0.000000       40.222222
# El-Salvador                   608.780000     15.790000       37.000000
# England                       904.941860     86.604651       42.476744
# France                        587.555556      0.000000       46.370370
# Germany                       949.468750     83.460938       41.757812
# Greece                       1283.896552    295.448276       44.241379
# Guatemala                     234.492063     25.301587       39.222222
# Haiti                           0.000000     76.785714       37.166667
# Holand-Netherlands              0.000000   2205.000000       40.000000
# Honduras                        0.000000    158.500000       37.916667
# Hong                            0.000000    104.052632       40.947368
# Hungary                       716.615385    128.307692       35.615385
# India                        3604.920000    131.120000       41.530000
# Iran                         2093.333333    129.833333       44.071429
# Ireland                       324.458333     78.625000       42.416667
# Italy                         656.470588     29.073529       42.220588
# Jamaica                       481.075000      0.000000       38.575000
# Japan                        2594.559322     60.457627       43.966102
# Laos                          169.705882      0.000000       40.352941
# Mexico                        359.339344     25.396721       40.580328
# Nicaragua                     205.878788    103.848485       36.060606
# Outlying-US(Guam-USVI-etc)      0.000000      0.000000       41.857143
# Peru                           61.033333     61.600000       35.900000
# Philippines                  1072.510638    104.218085       39.601064
# Poland                        375.107143     36.625000       39.267857
# Portugal                      248.529412      0.000000       42.058824
# Puerto-Rico                   320.981651     57.761468       38.541284
# Scotland                        0.000000      0.000000       41.363636
# South                         698.309859    135.619718       44.464789
# Taiwan                       2607.119048    149.857143       40.833333
# Thailand                        0.000000      0.000000       47.411765
# Trinadad&Tobago                 0.000000    234.777778       37.222222
# United-States                1120.499782     90.272724       40.970986
# Vietnam                       691.562500     91.390625       38.234375
# Yugoslavia                    347.250000      0.000000       44.562500

# %%
#calculamos la autocorrelacion
data_limpia.corr()
#Sin considerar a income, solo los datos numericos
#Se observa que age, fnlwgt, education.num, capital.gain, capital.loss y hours.per.week tienen baja correlacion.
# Out:
#                      age    fnlwgt  education.num  capital.gain  capital.loss  \
# age             1.000000 -0.076511       0.043526      0.080154      0.060165
# fnlwgt         -0.076511  1.000000      -0.044992      0.000422     -0.009750
# education.num   0.043526 -0.044992       1.000000      0.124416      0.079646
# capital.gain    0.080154  0.000422       0.124416      1.000000     -0.032229
# capital.loss    0.060165 -0.009750       0.079646     -0.032229      1.000000
# hours.per.week  0.101599 -0.022886       0.152522      0.080432      0.052417
#
#                 hours.per.week
# age                   0.101599
# fnlwgt               -0.022886
# education.num         0.152522
# capital.gain          0.080432
# capital.loss          0.052417
# hours.per.week        1.000000

# %% [markdown]
# # Visualizaciones

# %%
#Educacion vs income para ver cual afecta mas, al ser muy alta puede ser un buen predictor
pd.crosstab(data_limpia.education, data_limpia.income).plot(kind="bar")
plt.title("Education - Income")
plt.xlabel("Education")
plt.ylabel("Income")
# Out:
# Text(0,0.5,'Income')

# %%
#Marital.statuts vs income para ver cual afecta mas
pd.crosstab(data_limpia["marital.status"] , data_limpia.income).plot(kind="bar")
plt.title("Marital.Status - Income")
plt.xlabel("Marital.Status")
plt.ylabel("Income")
# Out:
# Text(0,0.5,'Income')

# %%
#Occupation vs income para ver cual afecta mas, al ser muy alta puede ser un buen predictor
pd.crosstab(data_limpia["occupation"] , data_limpia.income).plot(kind="bar")
plt.title("occupation - Income")
plt.xlabel("occupation")
plt.ylabel("Income")
# Out:
# Text(0,0.5,'Income')

# %%
#relationship vs income para ver cual afecta mas, al ser muy alta puede ser un buen predictor
pd.crosstab(data_limpia["relationship"] , data_limpia.income).plot(kind="bar")
plt.title("relationship - Income")
plt.xlabel("relationship")
plt.ylabel("Income")
# Out:
# Text(0,0.5,'Income')

# %%
#race vs income para ver cual afecta mas
pd.crosstab(data_limpia["race"] , data_limpia.income).plot(kind="bar")
plt.title("race - Income")
plt.xlabel("racec")
plt.ylabel("Income")
# Out:
# Text(0,0.5,'Income')

# %%
#sex vs income para ver cual afecta mas
pd.crosstab(data_limpia["sex"] , data_limpia.income).plot(kind="bar")
plt.title("sex - Income")
plt.xlabel("sex")
plt.ylabel("Income")
# Out:
# Text(0,0.5,'Income')

# %%
#Nativecountry vs income para ver cual afecta mas
pd.crosstab(data_limpia["native.country"] , data_limpia.income).plot(kind="bar")
plt.title("native.country - Income")
plt.xlabel("native.country")
plt.ylabel("Income")
# Out:
# Text(0,0.5,'Income')

# %%
#Creo un nueveo dataset, no utilizo education-num, relationship, cappital.gain,capital.loss
data_limpia2=data_limpia[["age", "workclass", "fnlwgt", "education", "marital.status", "occupation", "race", "sex", "hours.per.week","native.country", "income" ]]
data_limpia2.head()
# Out:
#    age workclass  fnlwgt     education marital.status         occupation  \
# 1   82   Private  132870       HS-grad        Married    Exec-managerial
# 3   54   Private  140359       7th-8th        Married  Machine-op-inspct
# 4   41   Private  264663  Some-college        Married     Prof-specialty
# 5   34   Private  216864       HS-grad        Married      Other-service
# 6   38   Private  150601          10th        Married       Adm-clerical
#
#     race     sex  hours.per.week native.country income
# 1  White  Female              18  United-States  <=50K
# 3  White  Female              40  United-States  <=50K
# 4  White  Female              40  United-States  <=50K
# 5  White  Female              45  United-States  <=50K
# 6  White    Male              40  United-States  <=50K

# %% [markdown]
# # Aplico Dummies
# ## Las variables categoricas las convierto en zeros y unos

# %%
data_dummy=pd.get_dummies(data_limpia2)
data_dummy.head()
# Out:
#    age  fnlwgt  hours.per.week  workclass_Federal-gov  workclass_Local-gov  \
# 1   82  132870              18                      0                    0
# 3   54  140359              40                      0                    0
# 4   41  264663              40                      0                    0
# 5   34  216864              45                      0                    0
# 6   38  150601              40                      0                    0
#
#    workclass_Private  workclass_Self-emp-inc  workclass_Self-emp-not-inc  \
# 1                  1                       0                           0
# 3                  1                       0                           0
# 4                  1                       0                           0
# 5                  1                       0                           0
# 6                  1                       0                           0
#
#    workclass_State-gov  workclass_Without-pay     ...       \
# 1                    0                      0     ...
# 3                    0                      0     ...
# 4                    0                      0     ...
# 5                    0                      0     ...
# 6                    0                      0     ...
#
#    native.country_Scotland  native.country_South  native.country_Taiwan  \
# 1                        0                     0                      0
# 3                        0                     0                      0
# 4                        0                     0                      0
# 5                        0                     0                      0
# 6                        0                     0                      0
#
#    native.country_Thailand  native.country_Trinadad&Tobago  \
# 1                        0                               0
# 3                        0                               0
# 4                        0                               0
# 5                        0                               0
# 6                        0                               0
#
#    native.country_United-States  native.country_Vietnam  \
# 1                             1                       0
# 3                             1                       0
# 4                             1                       0
# 5                             1                       0
# 6                             1                       0
#
#    native.country_Yugoslavia  income_<=50K  income_>50K
# 1                          0             1            0
# 3                          0             1            0
# 4                          0             1            0
# 5                          0             1            0
# 6                          0             1            0
#
# [5 rows x 92 columns]
